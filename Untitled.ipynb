# %%
from importlib import reload

import numpy as np
import pandas as pd

import pwv_kpno

# %%
from pwv_kpno.downloads import DownloadManager

# DownloadManager().download_available_data('KITT')
# DownloadManager().download_available_data('AZAM')

# %%
m = pwv_kpno.gps_pwv.PWVModel('Kitt', ('AZAM',))

# %%
measured_pwv = m.weather_data()
modeled_pwv = m.modeled_pwv()

# %%
from matplotlib import pyplot as plt

plt.figure(figsize=(20, 10))
plt.scatter(modeled_pwv.index, modeled_pwv.PWV, s=1)
plt.scatter(measured_pwv.index, measured_pwv.PWV, s=1)
